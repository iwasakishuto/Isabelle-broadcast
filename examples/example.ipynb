# %% [markdown]
# # Example Notebook

# %%
from main import create_text_img, get_text

# %% [markdown]
# ## Main usage

# %%
! date
# Out:
# Sun Aug 16 14:04:12 JST 2020

# %%
text = get_text()
print(text)
# Out:
# みなさ〜ん、こんにちは！
# ただいまの　時刻は
# 2020年  08月  16日  日曜日の
# 午後02時04分です

# %%
create_text_img(text=text)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1018 at 0x10DB8D8B0>

# %% [markdown]
# ## Funny usage

# %%
create_text_img(text="しゅーとさ〜ん、こんにちは！\n院試の勉強しろ。\nパソコンぶっ壊すぞ。")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1018 at 0x10DDF9880>
